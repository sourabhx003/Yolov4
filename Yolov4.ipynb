# %% [markdown]
# <a href="https://colab.research.google.com/github/sourabhx003/Yolov4/blob/main/Yolov4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14691, done.
# remote: Total 14691 (delta 0), reused 0 (delta 0), pack-reused 14691
# Receiving objects: 100% (14691/14691), 13.25 MiB | 13.35 MiB/s, done.
# Resolving deltas: 100% (9994/9994), done.

# %%
# !nvidia-smi
# Out:
# Sat Feb 13 05:28:24 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/rathorology/Custom-Yolo
# Out:
# Cloning into 'Custom-Yolo'...
# remote: Enumerating objects: 2448, done.
# remote: Total 2448 (delta 0), reused 0 (delta 0), pack-reused 2448
# Receiving objects: 100% (2448/2448), 58.94 MiB | 31.66 MiB/s, done.
# Resolving deltas: 100% (246/246), done.

# %%
#Classes name :- F(Face),H & M (Helmet & Mask), M (Mask) ,H (Helmet)
# so number of classes = 4
#for the above dataset

# %%
#either use !sed or change directly the makefile.
#GPU=1
#CUDNN=1
#opencv=1
#and compile it using !make

# %%
# %cd darknet
# Out:
# /content/darknet

# %%
# !make

# %%
#import weights for yolov4

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
#  1.jpg				     Scan_20190302_193637.jpg
#  2.jpg				     Scan_20190302_193715_001.jpg
#  3.jpg				     Scan_20190302_193715_002.jpg
#  5.jpg				     Scan_20190302_193715.jpg
#  6.jpg				     Scan_20190302_193746_001.jpg
# 'Aadhar card-converted.pdf'	     Scan_20190302_193746_002.jpg
# 'Advance Tensorflow'		     Scan_20190302_193746_003.jpg
#  built_model			    'Scan Feb 5, 2021.pdf'
# 'Colab Notebooks'		    'Screenshot (49).png'
#  IMG_20201214_202915.jpg	    'SmartInternz - Certificate.pdf'
#  IMG_20210204_111240-converted.pdf  'SourabhSingh-Resume (1).pdf'
#  in.gov.cbse-HPCER-66045312017.pdf   SourabhSinghResume1.pdf
# 'My Certificates'		    'SourabhSingh-Resume (2).pdf'
# 'NN algos'			    'SourabhSingh-Resume (3).pdf'
#  Resume				     SourabhSingh-Resume.pdf
#  Resume.gdoc			     u.jpg
#  Scan_20190302_193602.jpg	     Untitled-138.jpg
#  Scan_20190302_193637_001.jpg	     yolov4

# %%
#change cfg/yolov4-custom.cfg
#either by using !sid or directly in colab
#for all three yolo layers
# classes = 4
# batch = 64
#subdivision = 16 if out of memory occurs increase the value to 32,64
#max_batches = number_of_class*2000
#filters above every yolo = (4+5)*3

# %%
#create obj.names under darknet/data
#with each class in every new line
#in our case 
#F(Face)
#H & M (Helmet & Mask)
#M (Mask)
#H (Helmet)

# %%
#copy configuration file and obj.names file into the gdrive for later uses

# %%
# !cp data/obj.names /mydrive/yolov4/classes.txt
# !cp cfg/yolov4-custom.cfg /mydrive/yolov4/yolov4_custom.cfg

# %%
#create obj.data under darknet/data
#classes = 4
#train = data/train.txt
#valid = data/test.txt
#name = data/obj.names
#backup = /mydrive/yolov4

# %%
#make directory in darknet/data to store our images and text file of the bounding boxes

# %%
# !mkdir data/obj

# %%
#copy or move your images and respective text file into the data/obj folder

# %%
# !cp /content/Custom-Yolo/custom_data/images/* /content/darknet/data/obj
# !cp /content/Custom-Yolo/custom_data/labels/* /content/darknet/data/obj

# %%
#create train.txt file in darknet/data

# %%
from glob import glob
image_list = glob("data/obj/*.jpg")
with open("data/train.txt","w") as file:
  for new_file in image_list:
    file.write(new_file+"\n")

# %%
#start training the model
# ! ./darknet detector train data/obj.data cfg/yolov4-custom.cfg /mydrive/yolov4/yolov4.conv.137
# ! ./darknet detector train data/obj.data cfg/yolov4-custom.cfg darknet53.conv.74

# ! ./darknet detector train
# data/obj.data----> identify training information
# cfg/yolov4-custom.cfg ------> for configuration
# darknet53.conv.74 || mydrive/yolov4 ----> for checking pretrained weights

# %%
 # ! ./darknet detector train data/obj.data cfg/yolov4-custom.cfg darknet53.conv.74 -map

 ####use -map only if you have test.txt file
 # 0r the error will be
 """
 CUDA-version: 10010 (11020), cuDNN: 7.6.5, GPU count: 1  
 OpenCV version: 3.2.0

 Error: There is no data/test.txt file for mAP calculation!
 Don't use -map flag.
 Or set valid=data/train.txt in your data/obj.data file.
 """
# Out:
# "\nCUDA-version: 10010 (11020), cuDNN: 7.6.5, GPU count: 1  \nOpenCV version: 3.2.0\n\nError: There is no data/test.txt file for mAP calculation!\nDon't use -map flag.\nOr set valid=data/train.txt in your data/obj.data file.\n"

# %%
! ./darknet detector train data/obj.data cfg/yolov4-custom.cfg /mydrive/yolov4/yolov4.conv.137 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.653417), count: 16, class_loss = 24.659967, iou_loss = 277.421906, total_loss = 302.081879
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.687457), count: 6, class_loss = 9.246442, iou_loss = 37.936607, total_loss = 47.183048
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.000000), count: 1, class_loss = 0.230471, iou_loss = 0.000000, total_loss = 0.230471
#  total_bbox = 804103, rewritten_bbox = 0.025494 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000475, iou_loss = 0.000000, total_loss = 0.000475
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.004871, iou_loss = 0.000000, total_loss = 0.004871
# ...
